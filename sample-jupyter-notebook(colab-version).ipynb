# %% [markdown]
# ## This is a Jupyter Notebook that shows the basics about how to use Jupyter Notebooks along with Anaconda managed environments

# %%
1+1
# Out:
# 2

# %%
from functools import reduce
name_list = ['PersonName1', 'PersonName2', 'PersonName3']
my_welcome_message_list = [f'Hello {name} ! Be welcome !' for name in sorted(name_list)]
my_welcome_message_list.append('Hello Everyone else !')
# for person_greetment in my_welcome_message_list:
#     print(person_greetment)
print(reduce(lambda x,y:f'{x} {y}',my_welcome_message_list,'=> '))
# Out:
# =>  Hello PersonName1 ! Be welcome ! Hello PersonName2 ! Be welcome ! Hello PersonName3 ! Be welcome ! Hello Everyone else !

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ## Hello World !
#
# This is a markdown text test !

# %% [markdown]
# The pandas read_csv method below loads data from a csv and creates a dataframe with that data:

# %%
df = pd.read_csv("https://raw.githubusercontent.com/danielpm1982/sample-jupyter-notebook/master/heart-disease.csv")

# %% [markdown]
# The pandas head() method shows the dataframe data:

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# You can restrain the number of rows shown, as below (only three rows):

# %%
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %% [markdown]
# Let's try plotting a graph calculating the value_counts of the pandas dataframe above - 'target' column, along with matplotlib:

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# Now let's display an image from our project uploaded resources with \!\[]\("image-name") markup code:

# %% [markdown]
# ![](https://github.com/danielpm1982/sample-jupyter-notebook/blob/master/6-step-ml-framework.png?raw=1)

# %% [markdown]
# You can use thus Jupyter notebooks as this for organizing the whole DS+ML project for each framework step, as below:

# %% [markdown]
# ## 1. Problem Definition
# Predict heart disease

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ## 3. Evaluation

# %% [markdown]
# ## 4. ETC

# %% [markdown]
# You can also run shell commands, as well:

# %%
ls
# Out:
# sample_data/

# %% [markdown]
# ### Therefore, the root of our environment contains:
#
# - the environment folder with our DS+ML libs and tools (imported and used at the code - no need for external dependencies)
# - instead of sharing online the whole env folder, we can simply export its configs to an environment yaml file (conda env export) and the user would recreate it locally from that yaml file (conda env create --file)
# - other than the environment with dependencies recreated locally, the resources (images, videos, csv data, etc - not the libs or tools) should be cloned locally along with the remote project, as those resources are to be used at the jupyter-notebook kernel for the project processing and visualization
# - and finally, the jupyter-notebook .ipynb containing the whole DS+ML runnable project code and markup, as well as the processed data outputs / visualizations
